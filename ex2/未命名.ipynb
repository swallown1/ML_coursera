# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import  expit

x_test = np.arange(-20,20,0.1)
y_test = expit(x_test)
plt.title("this is sigmiod function",fontsize="20")
plt.plot(x_test,y_test)
plt.grid(True)
